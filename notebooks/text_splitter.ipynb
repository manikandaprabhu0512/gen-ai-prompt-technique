# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text = "Today, I want to speak from the heart about three pillars that define the future of our nation: our youth, our education system, and our farmers."

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=5)
# chunks = splitter.split_text(text)
# chunks

# %% [markdown]
# ### Document Text Loader

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/speech.txt")
text = loader.load()
onePage = text[0].page_content

# %%
doc_chunks = splitter.split_documents(text)
doc_chunks

# %% [markdown]
# ### PDF Splitter

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/medical_report.pdf")
docs = loader.load()

# %%
chunks = splitter.split_documents(docs)
chunks
