# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
prompts = [
    {
        "role": "system",
        "content": "You are a helpful assistant that translates English to French."
    },
    {
        "role": "user",
        "content": "I love programming."
    }
]

res = llm.invoke(prompts)

# %%
print(res.content)

# %% [markdown]
# ### Prompt Templates - Dynammic Templates

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
out = StrOutputParser()

# %%
prompts = ChatPromptTemplate.from_messages([
    {
        "role": "system",
        "content": "You are a helpful assistant that translates English to {language}."
    },
    {
        "role": "user",
        "content": "{query}"
    }
])

# %%
final_prompt = prompts.format_messages(language="Tamlish", query="How are you?")

# %%
res = llm.invoke(final_prompt)

# %%
print(res.content)

# %%
res = llm.invoke(prompts.invoke({"language":"Kannada", "query" : "I love youuuuu."}))

# %%
print(res.content)

# %%
def transform(result : str):
    return result.upper()

# %%
chains = prompts | llm | out | transform

# %%
res = chains.invoke({"language":"Hinglish", "query" : "I love youuuuu."})

# %%
print(res)

# %%
prompts = [
    {"role" : "user", "content" : "My name is Manikanda Prabhu"},
    {"role" : "ai", "content" : "Hello Manikanda Prabhu! It's nice to meet you. How can I help you today?"},
    {"role" : "user", "content" : "What is my name?"}
]

res = llm.invoke(prompts)

# %%
res.content

# %% [markdown]
# ### Manage History

# %%
history = []
while True:
    query = input("User: ")
    if query.lower() in ["bye", "exit", "exit"]:
        print("Good Bye 😭")
        break

    history.append({"role" : "user", "content" : query})
    print("User: ", query)

    res = llm.invoke(history)
    history.append({"role" : "ai", "content" : res.content})
    print("AI: ", res.content, "\n")
