# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4")

# %%
res = llm.invoke("Who is current President of the United States?")
res.content

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = llm.invoke("Till which year knowledge you have?")
res.content

# %% [markdown]
# ### Static Prompt

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4")

# %%
prompts = [
    ("system", "You're a Python developer"),    ###(type, ) -> system, AI, user
    ("user", "How to sort a Array?")
]

res = llm.invoke(prompts)

# %%
print(res.content)
# Out:
# In Python, you can use the `sort()` function provided by Python lists to sort an array.
#
# Here is an example:
#
# ```python
# # defining the array
# my_array = [5, 2, 7, 3, 9, 1, 6, 4, 8]
# # sorting the array
# my_array.sort()
# # printing the sorted array
# print(my_array)
# ```
#
# This will sort the array in ascending order (from small to large). If you want to sort the array in descending order, you can use `sort()` function with `reverse=True` argument:
#
# ```python
# my_array.sort(reverse=True)
# ```
#
# Note: If you have an array with different types of data (such as strings and numbers mixed together), the `sort()` function might not work as expected, because these types are not directly comparable in Python. You'll need to convert them into a common type before sorting.
