# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="You're an agent. Who can search any question on google",
    checkpointer=InMemorySaver(),
)

# %%
question = "Tell me about Manikanda Prabhu from RV College of Engineering, Bengaluru"

# %%
response = agent.invoke(
    {"messages": [{"role": "user", "content": question}]},
    {"configurable": {"thread_id" : "1"}}
)

# %%
print(response['messages'][-1].content)

# %%
question1 = "Does he have any achivement in his name?"

# %%
response = agent.invoke(
    {"messages": [{"role": "user", "content": question1}]},
    {"configurable": {"thread_id" : "1"}}
)

# %%
print(response['messages'][-1].content)
