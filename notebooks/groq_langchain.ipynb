# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
google_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = google_llm.invoke("Can you explain me GEN-AI?")
print(res.content)
# Out:
# Absolutely! Let's break down Generative AI (GEN-AI) in a clear and understandable way.
#
# **What is Generative AI?**
#
# At its core, Generative AI is a type of artificial intelligence that can **create new and original content**. Instead of just analyzing or classifying existing data (like traditional AI), Generative AI learns the patterns and structures within data and then uses that knowledge to produce something entirely new.
#
# Think of it like this:
#
# *   **Traditional AI (Discriminative AI):** Imagine showing a child pictures of cats and dogs and asking them to identify which is which. They learn to *discriminate* between the two.
# *   **Generative AI:** Now imagine that child, after seeing many cats and dogs, can *draw* a picture of a cat or a dog that looks realistic, even if it's a breed they've never seen before. That's generative power.
#
# **How Does it Work (The Basics)?**
#
# Generative AI models are trained on massive datasets of existing content. This content can be text, images, audio, video, code, or even more complex data. During training, the AI learns:
#
# 1.  **Patterns and Relationships:** It identifies how words are used together, how colors and shapes form objects, how musical notes create melodies, etc.
# 2.  **Underlying Structures:** It understands the grammar of language, the composition of images, the rhythm of music, and so on.
# 3.  **Statistical Distributions:** It learns the probability of certain elements appearing together or in a certain order.
#
# Once trained, when you give it a **prompt** (an instruction or a starting point), the AI uses its learned knowledge to generate new content that statistically resembles the training data. It essentially predicts the most likely next piece of content based on what it has learned.
#
# **Key Concepts and Technologies:**
#
# While the underlying math can be complex, here are some key concepts and common architectures:
#
# *   **Large Language Models (LLMs):** These are the brains behind many text-based Generative AI tools (like me!). They are trained on vast amounts of text and can generate human-like text, translate languages, write different kinds of creative content, and answer your questions in an informative way. Examples include GPT-3, GPT-4, LaMDA, and Bard.
# *   **Diffusion Models:** These are very popular for image generation. They work by starting with random noise and gradually "denoising" it, guided by a prompt, until a coherent image emerges. Examples include DALL-E 2, Midjourney, and Stable Diffusion.
# *   **Generative Adversarial Networks (GANs):** These involve two neural networks, a "generator" that creates content and a "discriminator" that tries to tell if the content is real or fake. They compete, with the generator getting better at creating realistic content and the discriminator getting better at detecting fakes. GANs are used for images, video, and more.
# *   **Transformers:** This is a neural network architecture that has been incredibly influential, especially for LLMs. It excels at understanding the context and relationships between different parts of a sequence (like words in a sentence).
#
# **What Can Generative AI Do? (Use Cases)**
#
# The applications of Generative AI are rapidly expanding and are quite diverse:
#
# *   **Text Generation:**
#     *   Writing articles, blog posts, poems, scripts, emails.
#     *   Summarizing long documents.
#     *   Translating languages.
#     *   Answering questions and providing information.
#     *   Generating code.
#     *   Creating marketing copy.
# *   **Image Generation:**
#     *   Creating original artwork and illustrations.
#     *   Generating realistic or stylized images from text descriptions.
#     *   Editing and manipulating existing images.
#     *   Designing product prototypes.
# *   **Audio and Music Generation:**
#     *   Composing music in various styles.
#     *   Generating realistic speech and voiceovers.
#     *   Creating sound effects.
# *   **Video Generation:**
#     *   Creating short video clips from text prompts.
#     *   Animating still images.
# *   **3D Model Generation:**
#     *   Creating 3D objects and environments for games, VR/AR, and design.
# *   **Drug Discovery and Material Science:**
#     *   Designing new molecules and materials with desired properties.
# *   **Personalized Content:**
#     *   Tailoring educational materials, marketing messages, and entertainment.
#
# **Benefits of Generative AI:**
#
# *   **Creativity and Innovation:** Unlocks new possibilities for creative expression and problem-solving.
# *   **Efficiency and Automation:** Automates repetitive tasks and speeds up content creation.
# *   **Personalization:** Enables highly tailored experiences for users.
# *   **Accessibility:** Can make complex creative tools more accessible to a wider audience.
# *   **Discovery:** Helps in exploring new ideas and possibilities in fields like science and art.
#
# **Challenges and Ethical Considerations:**
#
# Generative AI also comes with significant challenges:
#
# *   **Bias:** Models can inherit biases from the data they are trained on, leading to unfair or discriminatory outputs.
# *   **Misinformation and Deepfakes:** The ability to generate realistic fake content raises concerns about the spread of misinformation and manipulation.
# *   **Copyright and Ownership:** Questions arise about who owns the copyright of AI-generated content.
# *   **Job Displacement:** Automation through AI could impact certain job roles.
# *   **Environmental Impact:** Training large AI models requires significant computational power and energy.
# *   **Hallucinations:** AI can sometimes generate plausible-sounding but factually incorrect information.
#
# **In a Nutshell:**
#
# Generative AI is a powerful new frontier in artificial intelligence that allows machines to create. It's trained on vast amounts of data to learn patterns and then uses that knowledge to generate novel text, images, audio, and more. While it offers incredible potential for innovation and efficiency, it also presents important ethical and societal questions that need careful consideration.
#
# I hope this explanation is helpful! Do you have any specific aspects of Generative AI you'd like to explore further?
